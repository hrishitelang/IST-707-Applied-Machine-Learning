# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('HW4-data-fedPapers85.csv')
dataset
# Out:
#      author            filename      a    all   also     an    and    any  \
# 0     dispt    dispt_fed_49.txt  0.280  0.052  0.009  0.096  0.358  0.026
# 1     dispt    dispt_fed_50.txt  0.177  0.063  0.013  0.038  0.393  0.063
# 2     dispt    dispt_fed_51.txt  0.339  0.090  0.008  0.030  0.301  0.008
# 3     dispt    dispt_fed_52.txt  0.270  0.024  0.016  0.024  0.262  0.056
# 4     dispt    dispt_fed_53.txt  0.303  0.054  0.027  0.034  0.404  0.040
# ..      ...                 ...    ...    ...    ...    ...    ...    ...
# 80  Madison  Madison_fed_45.txt  0.136  0.054  0.014  0.048  0.422  0.027
# 81  Madison  Madison_fed_46.txt  0.212  0.028  0.006  0.050  0.391  0.033
# 82  Madison  Madison_fed_47.txt  0.177  0.052  0.047  0.047  0.436  0.026
# 83  Madison  Madison_fed_48.txt  0.243  0.091  0.008  0.084  0.372  0.008
# 84  Madison  Madison_fed_58.txt  0.347  0.097  0.007  0.056  0.313  0.035
#
#       are     as  ...    was   were   what   when  which    who   will   with  \
# ...

# %%
dataset.describe()
# Out:
#                a        all       also         an        and        any  \
# count  85.000000  85.000000  85.000000  85.000000  85.000000  85.000000
# mean    0.293235   0.052835   0.007659   0.068388   0.384624   0.041612
# std     0.076799   0.023633   0.008409   0.029630   0.114493   0.022785
# min     0.096000   0.015000   0.000000   0.009000   0.217000   0.000000
# 25%     0.240000   0.035000   0.000000   0.049000   0.319000   0.025000
# 50%     0.299000   0.050000   0.007000   0.071000   0.358000   0.043000
# 75%     0.349000   0.066000   0.013000   0.085000   0.413000   0.056000
# max     0.466000   0.127000   0.047000   0.179000   0.821000   0.114000
#
#              are         as         at         be  ...        was       were  \
# count  85.000000  85.000000  85.000000  85.000000  ...  85.000000  85.000000
# mean    0.077071   0.124200   0.044271   0.301153  ...   0.025835   0.020224
# std     0.034450   0.040605   0.026210   0.086585  ...   0.029051   0.020868
# ...

# %%
for i in
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/dy/3d1m83kd219bvfl0ygpsjcd80000gn/T/ipykernel_36024/2534033099.py in <module>
#       3 for i in range(1, 11):
#       4     kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
# ----> 5     kmeans.fit(X)
#       6     wcss.append(kmeans.inertia_)
#       7 plt.plot(range(1, 11), wcss)
#
# NameError: name 'X' is not defined
